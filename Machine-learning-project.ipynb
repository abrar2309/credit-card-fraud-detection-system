# %% [markdown]
# CREDIT CARD FRAUD DETECTION SYSTEM
#
# >
#
#
# MACHINE LEARNING PROJECT
# **

# %% [markdown]
# IMPORTING NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# READ DATASET

# %%
df=pd.read_csv("/content/Fraud3.csv")
df.head()
# Out:
#    ID  LIMIT_BAL  Gender  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  ...  \
# 0   1      20000  Female   24      2      2     -1     -1     -2     -2  ...
# 1   2     120000  Female   26     -1      2      0      0      0      2  ...
# 2   3      90000  Female   34      0      0      0      0      0      0  ...
# 3   4      50000  Female   37      0      0      0      0      0      0  ...
# 4   5      50000    Male   57     -1      0     -1      0      0      0  ...
#
#    BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0        689          0          0          0         0       689         0
# 1       2682       3272       3455       3261         0      1000      1000
# 2      13559      14331      14948      15549      1518      1500      1000
# 3      49291      28314      28959      29547      2000      2019      1200
# 4      35835      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %% [markdown]
# **INITIAL INSPECTION**

# %%
print(df.shape)
# Out:
# (30000, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 22 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   Gender     30000 non-null  object
#  3   AGE        30000 non-null  int64
#  4   PAY_0      30000 non-null  int64
#  5   PAY_2      30000 non-null  int64
#  6   PAY_3      30000 non-null  int64
#  7   PAY_4      30000 non-null  int64
#  8   PAY_5      30000 non-null  int64
#  9   PAY_6      30000 non-null  int64
#  10  BILL_AMT1  30000 non-null  int64
#  11  BILL_AMT2  30000 non-null  int64
#  12  BILL_AMT3  30000 non-null  int64
#  13  BILL_AMT4  30000 non-null  int64
#  14  BILL_AMT5  30000 non-null  int64
#  15  BILL_AMT6  30000 non-null  int64
#  16  PAY_AMT1   30000 non-null  int64
#  17  PAY_AMT2   30000 non-null  int64
#  18  PAY_AMT3   30000 non-null  int64
#  19  PAY_AMT4   30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           AGE         PAY_0         PAY_2  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667     35.485500     -0.016700     -0.133767
# std     8660.398374   129747.661567      9.217904      1.123802      1.197186
# min        1.000000    10000.000000     21.000000     -2.000000     -2.000000
# 25%     7500.750000    50000.000000     28.000000     -1.000000     -1.000000
# 50%    15000.500000   140000.000000     34.000000      0.000000      0.000000
# 75%    22500.250000   240000.000000     41.000000      0.000000      0.000000
# max    30000.000000  1000000.000000     79.000000      8.000000      8.000000
#
#               PAY_3         PAY_4         PAY_5         PAY_6      BILL_AMT1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000
# mean      -0.166200     -0.220667     -0.266200     -0.291100   51223.330900
# ...

# %% [markdown]
# **DISPLAY OF NULL VALUES**

# %%
print(df.isna())
# Out:
#           ID  LIMIT_BAL  Gender    AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0      False      False   False  False  False  False  False  False  False
# 1      False      False   False  False  False  False  False  False  False
# 2      False      False   False  False  False  False  False  False  False
# 3      False      False   False  False  False  False  False  False  False
# 4      False      False   False  False  False  False  False  False  False
# ...      ...        ...     ...    ...    ...    ...    ...    ...    ...
# 29995  False      False   False  False  False  False  False  False  False
# 29996  False      False   False  False  False  False  False  False  False
# 29997  False      False   False  False  False  False  False  False  False
# 29998  False      False   False  False  False  False  False  False  False
# 29999  False      False   False  False  False  False  False  False  False
#
#        PAY_6  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# ...

# %%
 df.isna().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# Gender       0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# dtype: int64

# %%
df.head(25)
# Out:
#     ID  LIMIT_BAL  Gender  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  ...  \
# 0    1      20000  Female   24      2      2     -1     -1     -2     -2  ...
# 1    2     120000  Female   26     -1      2      0      0      0      2  ...
# 2    3      90000  Female   34      0      0      0      0      0      0  ...
# 3    4      50000  Female   37      0      0      0      0      0      0  ...
# 4    5      50000    Male   57     -1      0     -1      0      0      0  ...
# 5    6      50000    Male   37      0      0      0      0      0      0  ...
# 6    7     500000    Male   29      0      0      0      0      0      0  ...
# 7    8     100000  Female   23      0     -1     -1      0      0     -1  ...
# 8    9     140000  Female   28      0      0      2      0      0      0  ...
# 9   10      20000    Male   35     -2     -2     -2     -2     -1     -1  ...
# 10  11     200000  Female   34      0      0      2      0      0     -1  ...
# ...

# %%
df2=df.copy(deep=True)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(df2["Gender"])
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
df2.head()
# Out:
#    ID  LIMIT_BAL  Gender  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  ...  \
# 0   1      20000  Female   24      2      2     -1     -1     -2     -2  ...
# 1   2     120000  Female   26     -1      2      0      0      0      2  ...
# 2   3      90000  Female   34      0      0      0      0      0      0  ...
# 3   4      50000  Female   37      0      0      0      0      0      0  ...
# 4   5      50000    Male   57     -1      0     -1      0      0      0  ...
#
#    BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0        689          0          0          0         0       689         0
# 1       2682       3272       3455       3261         0      1000      1000
# 2      13559      14331      14948      15549      1518      1500      1000
# 3      49291      28314      28959      29547      2000      2019      1200
# 4      35835      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %% [markdown]
# **DUMMY VARIABLES
# **

# %%
pd.get_dummies(df2["Gender"])
# Out:
#        Female  Male
# 0           1     0
# 1           1     0
# 2           1     0
# 3           1     0
# 4           0     1
# ...       ...   ...
# 29995       0     1
# 29996       0     1
# 29997       0     1
# 29998       0     1
# 29999       0     1
#
# [30000 rows x 2 columns]

# %%
df2.corr()
# Out:
# <ipython-input-38-e0c6714eb3b3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                  ID  LIMIT_BAL       AGE     PAY_0     PAY_2     PAY_3  \
# ID         1.000000   0.026179  0.018678 -0.030575 -0.011215 -0.018494
# LIMIT_BAL  0.026179   1.000000  0.144713 -0.271214 -0.296382 -0.286123
# AGE        0.018678   0.144713  1.000000 -0.039447 -0.050148 -0.053048
# PAY_0     -0.030575  -0.271214 -0.039447  1.000000  0.672164  0.574245
# PAY_2     -0.011215  -0.296382 -0.050148  0.672164  1.000000  0.766552
# PAY_3     -0.018494  -0.286123 -0.053048  0.574245  0.766552  1.000000
# PAY_4     -0.002735  -0.267460 -0.049722  0.538841  0.662067  0.777359
# PAY_5     -0.022199  -0.249411 -0.053826  0.509426  0.622780  0.686775
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("/content/creditcard.csv")

# Increase all values in the dataset by a factor (e.g., 2 for doubling values)
factor = 0.75
df = df * factor

# Save the modified dataset to a new file or overwrite the existing one
df.to_csv("/content/creditcard_modified.csv", index=False)

# %%
df=pd.read_csv("/content/creditcard_modified.csv")
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  3.744788e-16 -9.871971e-16 -4.914310e-16
# V2     -0.010593  3.744788e-16  1.000000e+00 -9.915195e-16 -1.851446e-17
# V3     -0.419618 -9.871971e-16 -9.915195e-16  1.000000e+00 -8.327114e-16
# V4     -0.105260 -4.914310e-16 -1.851446e-17 -8.327114e-16  1.000000e+00
# V5      0.173072  2.344380e-16 -4.445577e-17 -3.397252e-15 -1.952348e-15
# V6     -0.063016  3.441144e-16  4.139450e-16  1.552890e-15  9.427042e-18
# V7      0.084714 -1.794195e-16  1.299787e-16  4.076447e-16 -5.556278e-16
# V8     -0.036949 -7.069690e-18 -1.389296e-16 -2.245715e-16  5.538956e-16
# V9     -0.008660 -2.732278e-16 -2.320194e-16  1.745368e-16  4.736881e-16
# V10     0.030617  5.874466e-17 -2.560941e-16  2.527374e-16 -1.066730e-17
# V11    -0.247689  5.994829e-16  4.922733e-16 -1.150810e-15 -2.599656e-16
# ...

# %% [markdown]
# ## **SIMPLE LINEAR REGRESSION**
#
#  DETERMINING X AND Y FOR SLR

# %%
import numpy as np

# %%
import pandas as pd

# Load your dataset into a DataFrame (replace 'your_dataset.csv' with your actual file name)
df1 = pd.read_csv('/content/Fraud3.csv')

# Now you can use the corr() method
df1.corr()
# Out:
# <ipython-input-39-a7d62eaa8303>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                  ID  LIMIT_BAL       AGE     PAY_0     PAY_2     PAY_3  \
# ID         1.000000   0.026179  0.018678 -0.030575 -0.011215 -0.018494
# LIMIT_BAL  0.026179   1.000000  0.144713 -0.271214 -0.296382 -0.286123
# AGE        0.018678   0.144713  1.000000 -0.039447 -0.050148 -0.053048
# PAY_0     -0.030575  -0.271214 -0.039447  1.000000  0.672164  0.574245
# PAY_2     -0.011215  -0.296382 -0.050148  0.672164  1.000000  0.766552
# PAY_3     -0.018494  -0.286123 -0.053048  0.574245  0.766552  1.000000
# PAY_4     -0.002735  -0.267460 -0.049722  0.538841  0.662067  0.777359
# PAY_5     -0.022199  -0.249411 -0.053826  0.509426  0.622780  0.686775
# ...

# %% [markdown]
# # DEFINING WHAT IS X AND Y FOR THE DATA MODEL
#
# ## Declaration and initialization

# %%
x=df1[["PAY_3"]]
y=df1.PAY_0

# %% [markdown]
# # Dividing into Train and Test Data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %% [markdown]
# # **BUILDING A REGRESSION MODEL FOR THE PROBLEM STATEMENT**

# %%
from sklearn.linear_model import LinearRegression

slr=LinearRegression()
slr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
slr.coef_
# Out:
# array([0.5375285])

# %%
slr.intercept_
# Out:
# 0.0720793964567766

# %%
ypred=slr.predict(x_test)

# %%
ypred
# Out:
# array([ 1.14713639,  0.0720794 ,  0.0720794 , ..., -1.0029776 ,
#        -0.4654491 , -1.0029776 ])

# %%
from sklearn.metrics import mean_absolute_error, r2_score
r2_score(y_test,ypred)
# Out:
# 0.3421683597533425

# %% [markdown]
# # predicting PAY_3 for the PAY_0

# %%
import numpy as np
x_new=np.array([5000]).reshape(1,-1)
slr.predict(x_new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2687.71457513])

# %% [markdown]
# ## Predicting time for new values of V9

# %%
# Load your dataset
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.metrics import accuracy_score
df=pd.read_csv("/content/Fraud3.csv")
x=df[["PAY_3","PAY_2"]]
y=df.PAY_0
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
mlr=LinearRegression()
mlr.fit(x_train,y_train)
print(mlr.coef_)
print(mlr.intercept_)
ypred=mlr.predict(x_test)
r2=r2_score(y_test,ypred)
print("r 2 score:",r2)
xnew=np.array([[5000,2,]])
prediction=mlr.predict(xnew)
print("prediction",prediction)
# Out:
# [0.14171203 0.51644643]
# 0.07567821044789659
# r 2 score: 0.4949214966531902
# prediction [709.66874471]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble  import RandomForestRegressor
rreg=RandomForestRegressor(n_estimators=10)
rreg.fit(x_train,y_train)
pred=rreg.predict(x_test)
lf=r2_score(y_test,pred)
rmse=np.sqrt(mean_squared_error(y_test,pred))
print(lf)
print(rmse)
# Out:
# 0.5388316909214155
# 0.7682566328903199

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Fraud3.csv")
df.head()
# Out:
#    ID  LIMIT_BAL  Gender  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  ...  \
# 0   1      20000  Female   24      2      2     -1     -1     -2     -2  ...
# 1   2     120000  Female   26     -1      2      0      0      0      2  ...
# 2   3      90000  Female   34      0      0      0      0      0      0  ...
# 3   4      50000  Female   37      0      0      0      0      0      0  ...
# 4   5      50000    Male   57     -1      0     -1      0      0      0  ...
#
#    BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0        689          0          0          0         0       689         0
# 1       2682       3272       3455       3261         0      1000      1000
# 2      13559      14331      14948      15549      1518      1500      1000
# 3      49291      28314      28959      29547      2000      2019      1200
# 4      35835      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 22 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   Gender     30000 non-null  object
#  3   AGE        30000 non-null  int64
#  4   PAY_0      30000 non-null  int64
#  5   PAY_2      30000 non-null  int64
#  6   PAY_3      30000 non-null  int64
#  7   PAY_4      30000 non-null  int64
#  8   PAY_5      30000 non-null  int64
#  9   PAY_6      30000 non-null  int64
#  10  BILL_AMT1  30000 non-null  int64
#  11  BILL_AMT2  30000 non-null  int64
#  12  BILL_AMT3  30000 non-null  int64
#  13  BILL_AMT4  30000 non-null  int64
#  14  BILL_AMT5  30000 non-null  int64
#  15  BILL_AMT6  30000 non-null  int64
#  16  PAY_AMT1   30000 non-null  int64
#  17  PAY_AMT2   30000 non-null  int64
#  18  PAY_AMT3   30000 non-null  int64
#  19  PAY_AMT4   30000 non-null  int64
# ...

# %% [markdown]
# **Convert categorical data into numerical data**

# %%
df2=df.copy(deep=True)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(df2["Gender"])
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
x=df2[["PAY_4"]]
y=df2.PAY_5
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3,metric='euclidean')
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
ypred=knn.predict(x_test)
print(ypred)
# Out:
# [ 0  0  0 ... -2 -1 -2]

# %%
from sklearn.metrics import classification_report,accuracy_score
print(accuracy_score(y_test,ypred))
# Out:
# 0.8265

# %%
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#           -2       0.90      0.87      0.88       922
#           -1       0.70      0.73      0.72      1053
#            0       0.90      0.87      0.89      3398
#            2       0.57      0.74      0.64       546
#            3       0.57      0.19      0.28        43
#            4       0.89      0.42      0.57        19
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         1
#            7       0.93      0.93      0.93        15
#
#     accuracy                           0.83      6000
#    macro avg       0.61      0.53      0.55      6000
# weighted avg       0.83      0.83      0.83      6000
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
